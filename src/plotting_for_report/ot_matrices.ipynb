# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

# %%
# Change path!
x = torch.load("get_poster_ot/ot_matrix_/1-2.npy")
x_prob = torch.load("get_poster_ot/prob_matrix_get_poster_ot/1-2.npy")

# %%
c = plt.imshow(x, cmap='Greens')
plt.colorbar(c) 
plt.title('Unbalanced OT Matrix - Raw Entries')
plt.savefig("get_poster_ot/ot_matrix_/1-2.png", transparent=True)

# %%
c = plt.imshow(x_prob, cmap='Blues')

plt.colorbar(c) 
  
plt.title('Unbalanced OT Matrix - Uncertainty Scores')
plt.savefig("get_poster_ot/ot_matrix_/1-2p.png", transparent=True)
